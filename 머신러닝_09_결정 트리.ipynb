# %% [markdown]
# # 분류(classification)

# %% [markdown]
# - 지도학습의 대표적 유형
# - 학습 데이터로 주어진 데이터의 피처와 레이블값(결정값, 클래스값)을 머신러닝 알고리즘으로 학습해 모델을 생성하고 생성된 모델에 새로운 값이 주어졌을 때 미지의 레이블 값을 예측하는 것

# %% [markdown]
# ### 대표적인 분류 알고리즘
# - 결정 트리(Decision Tree)
# - 나이브 베이즈(Navie Bayes)
# - 로지스틱 회귀(Logistic Regression)
# - 서포트 벡터 머신(Support Vector Machine)
# - 최소 근접 알고리즘(Nearest Neighbor)
# - 신경망(Neural Network)
# - 앙상블(Ensemble)

# %% [markdown]
# ## 결정 트리(Decision Tree)
# - 학습을 통해 데이터에 있는 규칙을 자동으로 찾아내 트리 기반의 분류 규칙을 만드는 알고리즘
# - ML 알고리즘 중 직관적으로 이해하기 쉬운 알고리즘으로 분류와 회귀 문제에서 가장 널리 사용
# - 특정기준(질문)에 따라서 데이터를 구분
# - 가장 쉬운 규칙 표현 방법 : if/else 기반 (스무고개 게임과 유사)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 출처: https://ko.wikipedia.org/wiki/%EA%B2%B0%EC%A0%95_%ED%8A%B8%EB%A6%AC_%ED%95%99%EC%8A%B5%EB%B2%95

# %% [markdown]
# ### 의사결정나무의 타입
# - 분류 나무
#     - 범주형 목표 변수를 기준으로 마디를 나눔
#     - 끝마디에 포함된 자료의 범주가 분류 결과 값이 됨
#
# - 회귀 나무
#     - 연속형 목표 변수를 기준으로 마디를 나눔
#     - 끝마디에 포함된 자료의 평균값이 각 끝마디의 회귀 값이 됨

# %% [markdown]
# ### Tree 구조
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 결정트리에서 중요한 이슈
# - `규칙이 많아지면` 결정 방식이 복잡해지고 `과적합(overfitting)` 발생
#
#
# - 가능한 적은 결정노드로 높은 예측 정확도를 가지려면?
#
#
# - **`어떻게 트리를 분할할 것인가`가 중요**

# %% [markdown]
# ### 가지치기 (pruning)
# - 특정 노드 밑의 하부 트리를 제거하여 일반화 성능을 높이는 방법
# - 과적합(overfitting) 방지 방법

# %% [markdown]
# ### 결정트리의 장단점
#
# **장점**
# - 매우 쉽고 유연하게 적용될 수 있는 알고리즘
# - 정보 균일도 룰을 기반으로 알고리즘이 쉽고 직관적이며 명확함
# - 데이터 스케일링이나 정규화 등의 전처리 영향이 적음
#
# **단점**
# - 규칙이 많아지면 결정 방식이 복잡해지고 과적합(overfit) 발생
# - 즉, depth가 길어질수록 결정트리의 예측 성능이 저하될 가능성이 높음

# %% [markdown]
# ### 결정트리 알고리즘 성능
# - **`데이터의 어떤 기준을 바탕으로`** 규칙을 만들어야 `가장 효율적인 분류`가 될 것인가가 `알고리즘의 성능`을 크게 좌우
# - 가능한 적은 결정노드로 높은 예측 정확도를 가지려면
#     - 데이터를 분류할 때 최대한 많은 데이터 세트가 해당 분류에 속할 수 있도록 결정 노드의 규칙이 정해져야 함
# - 그러기 위해서는 **`어떻게 트리를 분할할 것인가가`** 중요
# - 최대한 균일한 데이터 세트를 구성할 수 있도록 분할하는 것이 필요

# %% [markdown]
#  ### 결정 트리 구조

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 균일도(불순도: impurity)
#
# - 규칙 조건 생성에서 중요한 것
# - 정보 균일도가 높은 데이터 세트를 먼저 선택할 수 있도록 규칙 조건을 만드는 것이 중요
#
# **균일한 데이터 세트**
# - 데이터 세트의 균일도는 데이터를 구분하는 데 필요한 정보의 양에 영향을 미침

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 엔트로피(Entropy)
# - 데이터 분포의 불순도(impurity)를 수치화한 지표
#
# ### 정보 이득 (Information Gain) 지수
# - 분류를 통해 정보에 대해 얻은 이득
# - **`1 - 엔트로피 지수`**
#
# ### 지니(Gini) 계수
# - 불순도(impurity)를 수치화한 지표
#
# ### 결정 트리 알고리즘에서 지니 계수 이용

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 결정 트리 알고리즘에서 분류를 결정하는 과정

# %% [markdown]
# **[분류 결정 과정]**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 사이킷런의 결정트리 알고리즘 클래스
#
# - 분류모델을 위한 **`DecisionTreeClassifier`**
# - 회귀모델을 위한 **`DecisionTreeRegressor`**
# - 분류와 회귀모델 모두 CART(Classification And Regression Tree) 알고리즘 기반
#
# - 결정 트리를 위한 클래스의 매개변수
#     - 분류, 회귀 모두 동일하게 적용
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 결정 트리 모델의 시각화(Decision Tree Visualization)

# %% [markdown]
# ### Graphviz 패키지 사용
# - 사이킷런에서 export_graphviz() API 제공
# - 학습된 결정 트리 규칙을 실제 트리 형태로 시각화

# %% [markdown]
# ### 붓꽃 데이터 세트에 결정 트리 적용 및 시각화
# - DecisionTreeClassifier 이용해 학습한 뒤
# - 규칙 트리 시각화

# %%
# 모듈 importing
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# DecisionTree Classifier 생성
dt_clf = DecisionTreeClassifier()

# 붓꽃 데이터를 로딩하고, 학습과 테스트 데이터 셋으로 분리
iris = load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11)

# DecisionTreeClassifer 학습. 
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
from sklearn import tree

tree.plot_tree(dt_clf)
# Out:
# [Text(111.60000000000001, 201.90857142857143, 'X[2] <= 2.45\ngini = 0.666\nsamples = 112\nvalue = [38, 39, 35]'),
#  Text(74.4, 170.84571428571428, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0]'),
#  Text(148.8, 170.84571428571428, 'X[3] <= 1.55\ngini = 0.499\nsamples = 74\nvalue = [0, 39, 35]'),
#  Text(74.4, 139.78285714285715, 'X[2] <= 5.25\ngini = 0.051\nsamples = 38\nvalue = [0, 37, 1]'),
#  Text(37.2, 108.72, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(111.60000000000001, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(223.20000000000002, 139.78285714285715, 'X[0] <= 6.05\ngini = 0.105\nsamples = 36\nvalue = [0, 2, 34]'),
#  Text(186.0, 108.72, 'X[0] <= 5.85\ngini = 0.408\nsamples = 7\nvalue = [0, 2, 5]'),
#  Text(148.8, 77.65714285714284, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(223.20000000000002, 77.65714285714284, 'X[1] <= 2.85\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ### sklearn.tree모듈은 Graphviz를 이용하기 위한 export_graphviz()함수 제공
#
# **export_graphviz() 함수**
#
# 매개변수
# - 학습이 완료된 estimator
# - output 파일명
# - 결정 클래스 명칭
# - 피처 이름
# - impurity=True : 각 노드에 불순도 표시 (gini 계수) (True: 디폴트)
# - filled=True : 노드 색상 표시 (False: 디폴트)

# %%
# 그래프 비즈 임포트
from sklearn.tree import export_graphviz

export_graphviz(dt_clf, out_file='tree1.dot', class_names=iris.target_names, 
                feature_names=iris.feature_names, impurity=True, filled=True)

# %%
# 생성된 .dot 파일 출력 방법 2가지
# 1. Graphviz 시각화툴 사용 : .dot 파일 읽어서 출력
# 2. 이미지 파일로 변환해서 저장 후 출력

# %%
# 1. Graphviz 시각화툴 사용 : .dot 파일 읽어서 출력

import graphviz

with open('tree1.dot') as f:
    dot_graph = f.read()

graphviz.Source(dot_graph)

# %% [markdown]
# ---

# %%
# 2. 생성된 .dot 파일을 .png 파일로 변환해서 저장 후 출력
from subprocess import call

call(['dot', '-Tpng', 'tree1.dot', '-o', 'decision_tree1.png', '-Gdpi=600'])

from IPython.display import Image
Image(filename='decision_tree1.png')

# %%
##### 참고 :

# %% [markdown]
# ## 결정 트리 하이퍼 파라미터 튜닝

# %% [markdown]
# - max_depth 조정

# %%
# 결정 트리 하이퍼 파라미터 튜닝1

dt_clf = DecisionTreeClassifier(max_depth=3, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='./output/tree2.dot',
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True,
               filled=True)

# 트리 시각화
with open('./output/tree2.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %%
# 결정 트리 하이퍼 파라미터 튜닝2

dt_clf = DecisionTreeClassifier(max_depth=4, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='./output/tree3.dot',
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True,
               filled=True)

# 트리 시각화
with open('./output/tree3.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %% [markdown]
# - min_samples_split 조정

# %%
# 결정 트리 하이퍼 파라미터 튜닝3

dt_clf = DecisionTreeClassifier(min_samples_split=4, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='./output/tree4.dot',
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True,
               filled=True)

# 트리 시각화
with open('./output/tree4.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %%
# 결정 트리 하이퍼 파라미터 튜닝4

dt_clf = DecisionTreeClassifier(min_samples_split=10, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='./output/tree5.dot',
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True,
               filled=True)

# 트리 시각화
with open('./output/tree5.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %% [markdown]
# - min_samples_leaf 조정

# %%
# 결정 트리 하이퍼 파라미터 튜닝5
dt_clf = DecisionTreeClassifier(min_samples_leaf=4, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='./output/tree6.dot',
               class_names=iris.target_names,
               feature_names=iris.feature_names,
               impurity=True,
               filled=True)

# 트리 시각화
with open('./output/tree6.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %%
visualize_boundary(dt_clf, X_train[:, [0,1]], y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/4086837677.py in <module>
# ----> 1 visualize_boundary(dt_clf, X_train[:, [0,1]], y_train)
#
# NameError: name 'visualize_boundary' is not defined

# %%
dt_clf_full = DecisionTreeClassifier()
visualize_boundary(dt_clf_full, X_train[:, [0,1]], y_train)

# %%
# 3가지 변수들 중 두가지 변수를 선택해서 visualize_boundary() 함수 적용해 분류 결과 시각화하기

# %%
# 파라미터의 값을 변화시켜 학습한 결정트리 시각화
# max_depth, min_sannple_split, min_sample_leaf

# %% [markdown]
# ### feature_importances_ 속성 (피처 중요도)
#
# * tree를 만드는 결정에 각 피처가 얼마나 중요한지 평가
# * 0과 1사이의 숫자
#
# **feature_

# %%
dt_clf.feature_importances_
# Out:
# array([0.01310846, 0.        , 0.543124  , 0.44376755])

# %%
# 피처별 중요도 값 확인하고 막대 그래프로 표현

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# feature별 importance 매핑

sns.barplot(x=dt_clf.feature_importances_, y=iris.feature_names)
# Out:
# <AxesSubplot:>

# %%
# feature_names을 X축으로 변경
sns.barplot(y=dt_clf.feature_importances_, x=iris.feature_names)
# Out:
# <AxesSubplot:>

# %%
# 피처 중요도 내림차순으로 막대 그래프 그리기

# %% [markdown]
# ## 결정 트리(Decision TREE) 과적합(Overfitting)

# %% [markdown]
# ### 결정 트리 과적합 시뮬레이션(시각화)
# - 사이키럿의 make_classification() 함수 사용
# - 2개의 피처가 3가지 유형의 클래스 값을 가지는 데이터 세트 생성하고 시각화

# %%
# 분류용 가상 데이터 생성하고 시각화
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# 2차원 시각화를 위해서 feature는 2개, 
# 결정값 클래스는 3가지 유형의 classification 샘플 데이터 생성. 
X_features, y_labels = make_classification(n_features=2, n_redundant=0, 
                                           n_informative=2,n_classes=3, 
                                           n_clusters_per_class=1,random_state=0)

# %%
X_features.shape
# Out:
# (100, 2)

# %%
y_labels
# Out:
# array([0, 1, 1, 1, 2, 2, 1, 0, 2, 2, 0, 1, 2, 1, 2, 0, 0, 1, 2, 1, 2, 0,
#        1, 2, 1, 0, 2, 2, 2, 0, 2, 1, 1, 0, 1, 0, 0, 2, 1, 0, 0, 1, 0, 2,
#        0, 2, 1, 0, 2, 0, 2, 2, 2, 1, 0, 1, 1, 0, 2, 0, 2, 0, 0, 2, 1, 1,
#        0, 1, 1, 2, 1, 0, 2, 2, 2, 0, 0, 1, 1, 0, 2, 1, 2, 1, 0, 2, 1, 1,
#        1, 1, 0, 0, 1, 0, 2, 2, 0, 2, 0, 0])

# %%
plt.scatter(X_features[:, 0], X_features[:, 1], marker='o', c=y_labels, s=25, cmap='rainbow', edgecolors='k')

# %% [markdown]
# - visualize_boundary(model, X, y) 함수 정의

# %%
# Classifier의 Decision Boundary를 시각화 하는 함수
# 클래스 값을 예측하는 결정 기준을 색상과 경계로 표시
def visualize_boundary(model, X, y):
    fig,ax = plt.subplots()
    
    # 학습 데이타 scatter plot으로 나타내기
    ax.scatter(X[:, 0], X[:, 1], c=y, s=25, cmap='rainbow', edgecolor='k',
               clim=(y.min(), y.max()), zorder=3)
    ax.axis('tight')
    ax.axis('off')
    xlim_start , xlim_end = ax.get_xlim()
    ylim_start , ylim_end = ax.get_ylim()
    
    # 호출 파라미터로 들어온 training 데이타로 model 학습 . 
    model.fit(X, y)
    # meshgrid 형태인 모든 좌표값으로 예측 수행. 
    xx, yy = np.meshgrid(np.linspace(xlim_start,xlim_end, num=200),np.linspace(ylim_start,ylim_end,
                                                                               num=200))
    # ravel() : 다차원을 1차원으로 품
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
    
    # contourf() 를 이용하여 class boundary 를 visualization 수행. 
    n_classes = len(np.unique(y))
    contours = ax.contourf(xx, yy, Z, alpha=0.3,
                           levels=np.arange(n_classes + 1) - 0.5,
                           cmap='rainbow', clim=(y.min(), y.max()), zorder=1)

# %%
# 특정한 트리 생성 제약없는 결정 트리의 Decsion Boundary 시각화.

dt_clf=DecisionTreeClassifier()
visualize_boundary(dt_clf, X_features, y_labels)
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_18244/1578155024.py:24: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %%
# min_samples_leaf=6 으로 트리 생성 조건을 제약한 Decision Boundary 시각화
dt_clf=DecisionTreeClassifier(min_samples_leaf=6)
visualize_boundary(dt_clf, X_features, y_labels)
# Out:
# C:\Users\82103\AppData\Local\Temp/ipykernel_18244/1578155024.py:24: UserWarning: The following kwargs were not used by contour: 'clim'
#   contours = ax.contourf(xx, yy, Z, alpha=0.3,

# %% [markdown]
# ## 결정 트리 실습 - Human Activity Recognition

# %% [markdown]
# 사용자 행동 인식 (Human Activity Recognition) 데이터 사용
# 수집된 피처 세트를 기반으로 결정 트리를 이용해서 어떠한 동작인지 예측

# %% [markdown]
# ### 사용자 행동 인식 (Human Activity Recognition) 데이터
#
# - 19~48세 연령대 30명에게 스마트폰 센서를 장착
# - 허리에 스마트폰을(삼성 갤럭시 S II) 착용하고 6가지 활동을 수행
#     - WALKING, WALKING_UPSTAIRS, WALKING_DOWNSTAIRS, SITTING, STANDING, LAYING
#
# - 내장 된 가속도계와 자이로스코프를 사용하여 50Hz의 일정한 속도로 3축 선형가속도와 3축 각속도를 캡처하여 동작과 관련된 속성 수집
# - UCI Machine Learning Repository : https://archive.ics.uci.edu/ml/datasets/human+activity+recognition+using+smartphones
#
# - features.txt :  561개 Feature 들어 있음 (index와 피처명)
#     - 피처명 : 인체의 움직임과 관련된 속성의 평균, 표준편차, ..,이 X, Y, Z축 값으로 되어 있음
#         - 가속도계의 3축 가속도 (총 가속도) 및 추정 된 신체 가속도
#         - 자이로 스코프로부터의 3 축 각속도
#         - 시간 및 주파수 도메인 변수가있는 561 특징 벡터
#         - 활동 라벨
#         - 실험을 수행 한 피험자의 식별자
#
# - X_train.txt : 561개 각 feauture에 대해 맵핑되는 속성값이 들어 있음

# %% [markdown]
# ### features.txt 파일 로드 후 피처 정보 출력

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# features.txt 파일에는 피처 이름 index와 피처명이 공백(\s+)으로 분리되어 있어서
# sep='\s+' 옵션 필요, DataFrame으로 로드 / 공백 이란걸 알려줌
feature_name_df = pd.read_csv('./datasets/human_activity/features.txt',
                             sep='\s+',
                             header=None,
                             names=['column_index', 'column_name'])
feature_name_df
# Out:
#      column_index                           column_name
# 0               1                     tBodyAcc-mean()-X
# 1               2                     tBodyAcc-mean()-Y
# 2               3                     tBodyAcc-mean()-Z
# 3               4                      tBodyAcc-std()-X
# 4               5                      tBodyAcc-std()-Y
# ..            ...                                   ...
# 556           557      angle(tBodyGyroMean,gravityMean)
# 557           558  angle(tBodyGyroJerkMean,gravityMean)
# 558           559                  angle(X,gravityMean)
# 559           560                  angle(Y,gravityMean)
# 560           561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %%
# index 제외하고 피처명만 추출해서 리스트 객체로 생성한 뒤 샘플로 10개만 추출
feature_name = feature_name_df.iloc[:, 1].values.tolist()
feature_name[:5]
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y']

# %% [markdown]
# ### 중복 피처 확인/변환

# %%
# 중복되지 않은 피처명 (unique) 개수 확인
feature_name_df['column_name'].unique().shape
# Out:
# (477,)

# %%
# 중복된 피처명 count
# 그룹별로 count : 1보다 크면 중복

feature_dup_df = feature_name_df.groupby('column_name').count()
feature_dup_df[feature_dup_df['column_index']>1]
# Out:
#                                   column_index
# column_name
# fBodyAcc-bandsEnergy()-1,16                  3
# fBodyAcc-bandsEnergy()-1,24                  3
# fBodyAcc-bandsEnergy()-1,8                   3
# fBodyAcc-bandsEnergy()-17,24                 3
# fBodyAcc-bandsEnergy()-17,32                 3
# fBodyAcc-bandsEnergy()-25,32                 3
# fBodyAcc-bandsEnergy()-25,48                 3
# fBodyAcc-bandsEnergy()-33,40                 3
# fBodyAcc-bandsEnergy()-33,48                 3
# fBodyAcc-bandsEnergy()-41,48                 3
# fBodyAcc-bandsEnergy()-49,56                 3
# fBodyAcc-bandsEnergy()-49,64                 3
# fBodyAcc-bandsEnergy()-57,64                 3
# fBodyAcc-bandsEnergy()-9,16                  3
# fBodyAccJerk-bandsEnergy()-1,16              3
# fBodyAccJerk-bandsEnergy()-1,24              3
# fBodyAccJerk-bandsEnergy()-1,8               3
# fBodyAccJerk-bandsEnergy()-17,24             3
# fBodyAccJerk-bandsEnergy()-17,32             3
# ...

# %% [markdown]
# ### 피처명 변경/반환하는 함수 get_new_feature_name_df()작성

# %%
# 중복된 피처명 변경하는 과정
# cumcount : 갯수를 세아리는데 똑같은게 있으면 누적으로 세기 때문에 0은 1개 있는 데이터 1부터는 2개이상

feature_cum_df = pd.DataFrame(data=feature_name_df.groupby('column_name').cumcount(),
                             columns=['dup_cnt'])
feature_cum_df[feature_cum_df['dup_cnt']>1]
# Out:
#      dup_cnt
# 330        2
# 331        2
# 332        2
# 333        2
# 334        2
# 335        2
# 336        2
# 337        2
# 338        2
# 339        2
# 340        2
# 341        2
# 342        2
# 343        2
# 409        2
# 410        2
# 411        2
# 412        2
# 413        2
# 414        2
# 415        2
# 416        2
# 417        2
# 418        2
# 419        2
# 420        2
# 421        2
# 422        2
# 488        2
# 489        2
# 490        2
# 491        2
# 492        2
# 493        2
# 494        2
# 495        2
# 496        2
# 497        2
# 498        2
# 499        2
# 500        2
# 501        2

# %%
feature_cum_df.shape
# Out:
# (561, 1)

# %%
# pd.groupby.cumcount()
x = pd.DataFrame(data=[['a'], ['b'], ['a'], ['c'], ['d'], ['a'], ['e'], ['c']], columns=['item'])
x
# Out:
#   item
# 0    a
# 1    b
# 2    a
# 3    c
# 4    d
# 5    a
# 6    e
# 7    c

# %%
# merge하기 위해 index 값을 갖는 열 필요
feature_name_df
# Out:
#      column_index                           column_name
# 0               1                     tBodyAcc-mean()-X
# 1               2                     tBodyAcc-mean()-Y
# 2               3                     tBodyAcc-mean()-Z
# 3               4                      tBodyAcc-std()-X
# 4               5                      tBodyAcc-std()-Y
# ..            ...                                   ...
# 556           557      angle(tBodyGyroMean,gravityMean)
# 557           558  angle(tBodyGyroJerkMean,gravityMean)
# 558           559                  angle(X,gravityMean)
# 559           560                  angle(Y,gravityMean)
# 560           561                  angle(Z,gravityMean)
#
# [561 rows x 2 columns]

# %%
feature_cum_df_reset = feature_cum_df.reset_index()
feature_cum_df_reset
# Out:
#      index  dup_cnt
# 0        0        0
# 1        1        0
# 2        2        0
# 3        3        0
# 4        4        0
# ..     ...      ...
# 556    556        0
# 557    557        0
# 558    558        0
# 559    559        0
# 560    560        0
#
# [561 rows x 2 columns]

# %%
feature_name_df_reset = feature_name_df.reset_index()
feature_name_df_reset
# Out:
#      index  column_index                           column_name
# 0        0             1                     tBodyAcc-mean()-X
# 1        1             2                     tBodyAcc-mean()-Y
# 2        2             3                     tBodyAcc-mean()-Z
# 3        3             4                      tBodyAcc-std()-X
# 4        4             5                      tBodyAcc-std()-Y
# ..     ...           ...                                   ...
# 556    556           557      angle(tBodyGyroMean,gravityMean)
# 557    557           558  angle(tBodyGyroJerkMean,gravityMean)
# 558    558           559                  angle(X,gravityMean)
# 559    559           560                  angle(Y,gravityMean)
# 560    560           561                  angle(Z,gravityMean)
#
# [561 rows x 3 columns]

# %%
# 두 데이터 프레임을 병합 : 피쳐 이름 데이터 프레임, 피터이름 카운트 데이터프레임
new_feature_name_df = pd.merge(feature_name_df_reset, feature_cum_df_reset, how='outer')
new_feature_name_df
# Out:
#      index  column_index                           column_name  dup_cnt
# 0        0             1                     tBodyAcc-mean()-X        0
# 1        1             2                     tBodyAcc-mean()-Y        0
# 2        2             3                     tBodyAcc-mean()-Z        0
# 3        3             4                      tBodyAcc-std()-X        0
# 4        4             5                      tBodyAcc-std()-Y        0
# ..     ...           ...                                   ...      ...
# 556    556           557      angle(tBodyGyroMean,gravityMean)        0
# 557    557           558  angle(tBodyGyroJerkMean,gravityMean)        0
# 558    558           559                  angle(X,gravityMean)        0
# 559    559           560                  angle(Y,gravityMean)        0
# 560    560           561                  angle(Z,gravityMean)        0
#
# [561 rows x 4 columns]

# %%
# 람다식 :
# 입력 : column_name, name_dup_cnt
# 반환 : 
# 즉, column'_'name_dup_cnt
# 아니면 [0] 값(첫 번째) 그래로 반환

new_feature_name_df['new_column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0] + '_' + str(x[1]) if x[1] > 0 else x[0], axis=1)
new_feature_name_df[new_feature_name_df['dup_cnt']>0]
new_feature_name_df = new_feature_name_df['new_column_name']

# %%
new_feature_name_df
# Out:
# 0                         tBodyAcc-mean()-X
# 1                         tBodyAcc-mean()-Y
# 2                         tBodyAcc-mean()-Z
# 3                          tBodyAcc-std()-X
# 4                          tBodyAcc-std()-Y
#                        ...
# 556        angle(tBodyGyroMean,gravityMean)
# 557    angle(tBodyGyroJerkMean,gravityMean)
# 558                    angle(X,gravityMean)
# 559                    angle(Y,gravityMean)
# 560                    angle(Z,gravityMean)
# Name: new_column_name, Length: 561, dtype: object

# %%
# 피처명 변경해서 반환하는 과정을 함수로 작성
# 피처명_1 또는 피처명_2로 변경
# groupby('column_name').cumcount() : 중복되는 값이 몇 번째에 해당되는지(index) 반환
# 0이면 첫 번째, 1이면 2번째...

def get_new_feature_name_df(old_df):
    # 1. old_feature_name_df의 열 이름 누적 카운트 계산한 데이터 프레임
    # 2 .1에서 생성한 데이터프레임의 인덱스를 reset_index    
    # 3. old_feature_name_df를 reset_index    
    # 4. 2,3의 두 데이터 프레임을 merge    
    # 5. 카운트 정보와 피처이름을 하나의 이름으로 변경 apply(lambda)    
    # 6. 필요한 컬럼만 저장
    
    dup_df = pd.DataFrame(data=old_df.groupby('column_name').cumcount(), columns=['dup_cnt'])
    dup_df = dup_df.reset_index()
    new_df = pd.merge(old_df.reset_index(), dup_df, how='outer')
    new_df['new_column_name'] = new_df[['column_name', 'dup_cnt']].apply(lambda x : x[0] + '_' + str(x[1]) if x[1] > 0 else x[0], axis=1)
    
    new_df = new_df[['new_column_name']]
    
    return new_df

# %%
# 채원님 코드

# def get_new_feature_name_df(df):
#     df['dup_cnt'] = pd.DataFrame(data =df.groupby('column_name').cumcount(), columns = ['dup_cnt'])
#     df['new_column_name'] = df[['column_name','dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1]) if x[1] > 0 else x[0], axis=1)
#     return df

# %% [markdown]
# ### 사용자 행동 인식 데이터 세트 준비 함수 : get_human_dataset( )

# %%
def get_human_dataset():
    feature_name_df = pd.read_csv('./datasets/human_activity/features.txt',
                             sep='\s+', header=None,
                             names=['column_index', 'column_name'])
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    feature_names = new_feature_name_df.iloc[:, -1].values.tolist()
    
    # 학습 데이터셋, 평가 데이터 피처셋 준비
    X_train = pd.read_csv('./datasets/human_activity/train/X_train.txt',
                             sep='\s+', names=feature_names)
    
    X_test = pd.read_csv('./datasets/human_activity/test/X_test.txt',
                             sep='\s+', names=feature_names)
    
    # 학습 데이터셋, 평가 데이터 타깃(레이블) 준비
    y_train = pd.read_csv('./datasets/human_activity/train/y_train.txt',
                             sep='\s+', header=None, names=['action'])
    
    y_test = pd.read_csv('./datasets/human_activity/test/y_test.txt',
                             sep='\s+', header=None, names=['action'])
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = get_human_dataset()

# %% [markdown]
# **학습 피처 데이터셋 정보**

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 561 entries, tBodyAcc-mean()-X to angle(Z,gravityMean)
# dtypes: float64(561)
# memory usage: 31.5 MB

# %%
# 학습용 피처 데이터 세트 확인
X_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
# null 값 확인
X_train.isna().sum()
# Out:
# tBodyAcc-mean()-X                       0
# tBodyAcc-mean()-Y                       0
# tBodyAcc-mean()-Z                       0
# tBodyAcc-std()-X                        0
# tBodyAcc-std()-Y                        0
#                                        ..
# angle(tBodyGyroMean,gravityMean)        0
# angle(tBodyGyroJerkMean,gravityMean)    0
# angle(X,gravityMean)                    0
# angle(Y,gravityMean)                    0
# angle(Z,gravityMean)                    0
# Length: 561, dtype: int64

# %%
X_train.isna().sum().sum()
# Out:
# 0

# %%
# 학습용 레이블 데이터 세트 확인
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   action  7352 non-null   int64
# dtypes: int64(1)
# memory usage: 57.6 KB

# %%
# 레이블 값 분포 확인 (각 값의 개수)
y_train['action'].value_counts()
# Out:
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: action, dtype: int64

# %%
# 레이블 값 확인 
y_train['action'].unique()
# Out:
# array([5, 4, 6, 1, 3, 2], dtype=int64)

# %% [markdown]
# ### DecisionTreeClassifier를 이용해서 동작 예측 분류 수행

# %%
# 모듈 임포트
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# 예제 반복 시 마다 동일한 예측 결과 도출을 위해 random_state = 156 설정
dt_clf = DecisionTreeClassifier(random_state=156)
# 학습
dt_clf.fit(X_train, y_train)
# 예측
pred = dt_clf.predict(X_test)
# 평가
print('accuracy :', np.round(accuracy_score(y_test, pred), 3))
# Out:
# accuracy : 0.855

# %%
# DecisionTreeClassifier의 하이퍼 파라미터 추출
dt_clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 156,
#  'splitter': 'best'}

# %% [markdown]
# ### 파라미터 튜닝 : GridSearchCV를 이용

# %%
# 결정 트리의 깊이(Tree Depth)가 예측 정확도에 미치는 영향 확인
# 교차 검증은 5개 세트 (cv=5)

from sklearn.model_selection import GridSearchCV

params = {'max_depth':[6, 8, 10, 12, 16, 20, 24]}

grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy', cv=5, verbose=1)

grid_cv.fit(X_train, y_train)

print('최적의 파라미터 : ', grid_cv.best_params_)

print('최고의 정확도 : ', grid_cv.best_score_)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# 최적의 파라미터 :  {'max_depth': 16}
# 최고의 정확도 :  0.8513444970102249

# %%
pd.DataFrame(grid_cv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.718618      0.045594         0.006988        0.000632
# 1       2.131536      0.041042         0.006981        0.001256
# 2       2.566543      0.045186         0.006406        0.000499
# 3       3.262035      0.318693         0.009248        0.001644
# 4       3.328500      0.364289         0.006992        0.000021
# 5       3.621886      0.485336         0.008022        0.000092
# 6       3.235579      0.353886         0.006788        0.000405
#
#   param_max_depth             params  split0_test_score  split1_test_score  \
# 0               6   {'max_depth': 6}           0.813732           0.872876
# 1               8   {'max_depth': 8}           0.820530           0.819850
# 2              10  {'max_depth': 10}           0.799456           0.814412
# 3              12  {'max_depth': 12}           0.794697           0.813052
# 4              16  {'max_depth': 16}           0.799456           0.818491
# ...

# %%
grid_cv_df = pd.DataFrame(grid_cv.cv_results_)

# %%
grid_cv_df[['param_max_depth', 'mean_test_score']]
# Out:
#   param_max_depth  mean_test_score
# 0               6         0.850791
# 1               8         0.851069
# 2              10         0.851209
# 3              12         0.844135
# 4              16         0.851344
# 5              20         0.850800
# 6              24         0.849440

# %% [markdown]
# - GridSearchCV객체의 cv_results_ 속성을 DataFrame으로 생성

# %% [markdown]
# - GridSearchCV를 사용하지 않고 max_depth 값을 변화시키면서 결정 트리의 최적의 성능 탐색

# %%
# max_depth 값을 변화시키면서 예측 성능 측정
max_depth = [6, 8, 10, 12, 16, 20, 24]

for depth in max_depth:
    dt_clf = DecisionTreeClassifier(max_depth=depth, random_state=156)
    dt_clf.fit(X_train, y_train)
    pred = dt_clf.predict(X_test)
    print(f'max_depth : {depth}, 정확도 : {accuracy_score(y_test, pred)}')
# Out:
# max_depth : 6, 정확도 : 0.8557855446216491
# max_depth : 8, 정확도 : 0.8707159823549372
# max_depth : 10, 정확도 : 0.8673227010519172
# max_depth : 12, 정확도 : 0.8646080760095012
# max_depth : 16, 정확도 : 0.8574821852731591
# max_depth : 20, 정확도 : 0.8547675602307431
# max_depth : 24, 정확도 : 0.8547675602307431

# %% [markdown]
# - max_depth와 min_samples_split을 같이 변경하면서 성능 튜닝

# %%
# max_depth와 min_samples_split을 같이 변경하면서 성능 튜닝
params = {'max_depth':[8,12,16,20],
'min_sample':[16,24]}

# 교차 검증
grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy',
                       cv=5, verbose=1)
grid_cv.fit(X_train, y_train)
print('GridSearchCV 최고 평균 정확도 수치 : {0:.4f}'.format(grid_cv.best_score_))
print('GridSearchCV 최적 하이퍼 파라미터:', grid_cv.best_params_)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/905216403.py in <module>
#       6 grid_cv = GridSearchCV(dt_clf, param_grid=params, scoring='accuracy',
#       7                        cv=5, verbose=1)
# ----> 8 grid_cv.fit(X_train, y_train)
#       9 print('GridSearchCV 최고 평균 정확도 수치 : {0:.4f}'.format(grid_cv.best_score_))
#      10 print('GridSearchCV 최적 하이퍼 파라미터:', grid_cv.best_params_)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %% [markdown]
# - 최적의 파라미터를 갖는 결정트리로 테스트 데이터 예측

# %%
best_dt_clf = grid_cv.best_estimator_

pred1 = best_dt_clf.predict(X_test)
print('결정 트리 예측 정확도 : {0:.4f}'.format(accuracy_score(y_test, pred1)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/1670483974.py in <module>
# ----> 1 best_dt_clf = grid_cv.best_estimator_
#       2
#       3 pred1 = best_dt_clf.predict(X_test)
#       4 print('결정 트리 예측 정확도 : {0:.4f}'.format(accuracy_score(y_test, pred1)))
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
X_test.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-meanFreq()', 'fBodyBodyGyroJerkMag-skewness()',
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)'],
#       dtype='object', length=561)

# %% [markdown]
# - 결정트리 시각화

# %%
dt_clf = 

graphviz

# %%
dt_clf = DecisionTreeClassifier(max_depth=4, random_state=156)
dt_clf.fit(X_train, y_train)

export_graphviz(dt_clf, out_file='dt_tree.dot',
               class_names=,
               feature_names=,
               impurity=True,
               filled=True)

# 트리 시각화
with open('dt_tree.dot') as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)

# %% [markdown]
# - 피처 중요도 확인

# %%
# 결정 트리에서 feature_importances_ 속성을 이용헤 각 피처의 중요도 확인
# 중요도가 높은 순으로 Top 20 피처를 막대그래프로 표현

plt.barplot(data=)
